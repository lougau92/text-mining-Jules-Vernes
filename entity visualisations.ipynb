# %%
import pickle
import re
# print the named entities frist 10
def load_nes(type):
    
    with open('./data/named_entities.pickle', 'rb') as f:
        i = 0

        nes_raw = [];
        while True:
            try:
                ne = pickle.load(f)
                # print all the GPE entities, GPE: Geopolitical Entity
                if ne.label() == type :nes_raw.append(str(ne))

            except EOFError:
                break
    return process_nes(nes_raw,type)

def process_nes(nes,type):
    transformed_nes = []
    i=0
    for ne in nes:
        loc = ne.replace('('+type+' ','')
        loc = re.sub(r'/[A-Z]+','',loc)
        loc = loc.replace(')','')
        if i<10: print(loc)
        i+=1
        transformed_nes.append(loc)

    return transformed_nes


# https://towardsdatascience.com/geoparsing-with-python-c8f4c9f78940
# https://geopy.readthedocs.io/en/stable/index.html#accessing-geocoders
import geopy
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
geopy.geocoders.options.default_user_agent = 'my_app/2'
geopy.geocoders.options.default_timeout = 2
geolocator = Nominatim()

def extract_locations(nes):
    lat_lon = []
    for ne in nes: 
        try:
            location = geolocator.geocode(ne)
            if location:
                # print(ne,location.latitude, location.longitude)
                lat_lon.append(location)
        except GeocoderTimedOut as e:  print("Error: geocode failed on input %s with message %s"%(ne, e))
    return lat_lon

# display the coordinates on a map
import folium
from folium.plugins import MarkerCluster, HeatMap
from lat_lon_parser import parse


# mc = MarkerCluster()
# mc.add_child(folium.Marker(location=[lat,long]))
# folium.Marker(location=[lat,long]).add_to(m)
#  add the marker cluster to the map
# m.add_child(mc)

def visualise_locations(lat_lon,name, heat = False, connected = False, data_type = 'locations'):
    # create a map
    m = folium.Map(location=[0, -150], zoom_start=2)

    if data_type == 'locations':    data = [[loc.latitude,loc.longitude] for loc in lat_lon]
    elif data_type == 'dataframe': 
        data = [     
            [parse(str(row['degrees_lat'])+'° '+str(row['minutes_lat'])+"' "+row['directio_lat']),
            parse(str(row['degrees_lon'])+'° '+str(row['minutes_lon'])+"' "+row['directio_lon'])]
            for idx, row in lat_lon.iterrows()
        ]


    if heat:   HeatMap(data).add_to(m)
    elif connected:
        for i in range(len(data)-1):
            folium.PolyLine(locations=[data[i],data[i+1]], weight=2, color='blue').add_to(m) 
    else:
        for d in data: folium.Marker(location=d).add_to(m)


    # save it as html
    title = name+'.html'
    if heat: title = 'heat_'+title
    elif connected: title = 'connected_'+title
    m.save('./plots/'+title)

    # display the map
    return m

# %%
gpes = load_nes('GPE')
gpe_lat_lon = extract_locations(gpes)
visualise_locations(gpe_lat_lon,'gpe',heat=True)
# Out:
# Europe
# America
# Australia
# Captain
# Similar
# Fifteen
# United States
# Europe
# Aleutian
# Kulammak
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48609e579948efee6025bf6aa8404972 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48609e579948efee6025bf6aa8404972&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48609e579948efee6025bf6aa8404972 = L.map(
#                 &quot;map_48609e579948efee6025bf6aa8404972&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_115f02a12db1e85c44a607a14746e8db = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map
510266, -102.16763], [-24.7761086, 134.755], [51.0, 10.0], [38.2565117, -7.1991347], [22.288113199999998, 114.27402216594173], [1.3827588, 103.8460242], [31.9510266, -102.16763], [36.1420267, -81.2880339], [31.9510266, -102.16763], [55.1173523, 61.6140242], [45.6432752, 4.6732572], [30.7582808, -97.5043115], [36.5748441, 139.2394179], [50.0926218, 14.401311], [46.603354, 1.8883335], [35.5438102, -98.0031532], [-0.3409562, 36.3720828], [-0.3409562, 36.3720828], [47.2339916, -1.6440057], [36.7675683, -84.9949508], [60.2340258, 9.8743057], [31.9510266, -102.16763], [60.2340258, 9.8743057], [35.5438102, -98.0031532], [35.5438102, -98.0031532], [43.810467450000004, 3.6596465572291703], [19.6145552, 77.2031164], [46.9831443, 23.0528248], [35.5438102, -98.0031532], [-23.2249383, -45.796

# %%
locations = load_nes('GPE')

def read_file(file_name):
    with open(file_name) as f:
        lines = f.readlines()
    return lines

path = './data/corefed_text.txt'

coref_text = read_file(path)[0]

import nltk
tokenizer = nltk.data.load("tokenizers/punkt/english.pickle")
coref_sentences = tokenizer.tokenize(coref_text)

# print the locations in their contexts
for i,sent in enumerate(coref_sentences):
    for loc in locations:
        subtext = ' '.join(coref_sentences[i-1:i+1])
        if loc in sent: print(loc,',',subtext)  ; print(); break
# Out:
# Europe
# America
# Australia
# Captain
# Similar
# Fifteen
# United States
# Europe
# Aleutian
# Kulammak
# No ,  PART ONE     CHAPTER I A SHIFTING REEF   The year 1866 was signalised by a remarkable incident, a mysterious and puzzling phenomenon, which doubtless no one has yet forgotten. Not to mention rumours which agitated the maritime population and excited the public mind, even in the interior of continents, seafaring men were particularly excited.
#
# Europe , Not to mention rumours which agitated the maritime population and excited the public mind, even in the interior of continents, seafaring men were particularly excited. Merchants, common sailors, captains of vessels, skippers, both of Europe and America, naval officers of all countries, and the Governments of several states on the two continents, were deeply interested in the matter.
#
# Australia , As to classing it in the list of fables, the idea was out of the question. On the 20th of July, 1866, the steamer _Governor Higginson_, of the Calcutta and Burnach Steam Navigation Company, had met this moving mass five miles off the east coast of Australia.
#
# Captain , On the 20th of July, 1866, the steamer _Governor Higginson_, of the Calcutta and Burnach Steam Navigation Company, had met this moving mass five miles off the east coast of Australia. Captain Baker thought at first that Captain Baker was in the presence of the sandbank; Captain Baker even prepared to determine he was in the presence of an unknown sandbank exact position, when two columns of water, projected by the inexplicable object, shot with a hissing noise a hundred and fifty feet up into the air.
#
# No , Captain Baker thought at first that Captain Baker was in the presence of the sandbank; Captain Baker even prepared to determine he was in the presence of an unknown sandbank exact position, when two columns of water, projected by the inexplicable object, shot with a hissing noise a hundred and fifty feet up into the air. Now, unless the sandbank had been submitted to the intermittent eruption of a geyser, the _Governor Higginson_ had to do neither more nor less than with an aquatic mammal, unknown till then, which threw up from the _Governor Higginson_ blow-holes columns of water mixed with air and vapour.
#
# Similar , Now, unless the sandbank had been submitted to the intermittent eruption of a geyser, the _Governor Higginson_ had to do neither more nor less than with an aquatic mammal, unknown till then, which threw up from the _Governor Higginson_ blow-holes columns of water mixed with air and vapour. Similar facts were observed on the 23rd of July in the same year, in the Pacific Ocean, by the _Columbus_, of the West India and Pacific Steam Navigation Company.
#
# Nebraska , In virtue of my office as Assistant Professor in the Museum of Natural History in Paris, the French Government had attached me to that expedition. After six months in Nebraska, I arrived in New York towards the end of March, laden with a precious collection.
#
# France , After six months in Nebraska, I arrived in New York towards the end of March, laden with a precious collection. My departure for France was fixed for the first days in May.
#
# Europe , How could I be otherwise? I had read and re-read all the American and European papers without being any nearer a conclusion.
#
# New York , That there really was something could not be doubted, and the incredulous were invited to put their finger on the wound of the _Scotia_. On my arrival at New York the question was at the question height.
#
# Certain , and how could a private gentleman should have such a machine at his command construction have been kept secret? Certainly a Government might possess such a destructive machine.
#
# Governments , At least, I hope so. But the hypothesis of a war machine fell before the declaration of Governments.
#
# America , For a private gentleman to keep the secret under such circumstances would be very difficult, and for a state whose every act is persistently watched by powerful rivals, certainly impossible. After inquiries made in England, France, Russia, Prussia, Spain, Italy, and America, even in Turkey, the hypothesis of a submarine monitor was definitely rejected.
#
# New York , After inquiries made in England, France, Russia, Prussia, Spain, Italy, and America, even in Turkey, the hypothesis of a submarine monitor was definitely rejected. Upon my arrival in New York several persons did me the honour of consulting me on the phenomenon in question.
#
# France , Upon my arrival in New York several persons did me the honour of consulting me on the phenomenon in question. I had published in France a work in quarto, in two volumes, entitled “Mysteries of the Great Submarine Grounds.” This book, highly approved of in the learned world, gained for me a special reputation in this rather obscure branch of Natural History.
#
# Paris , But soon, finding me driven into a corner, I was obliged to explain me categorically. And even “the Honourable Pierre Aronnax, Professor in the Museum of Paris,” was called upon by the _New York Herald_ to express a definite opinion of some sort.
#
# Nature , Either we do know all the varieties of beings which people we planet, or we do not. If we do _not_ know we do _—if Nature has still secrets in ichthyology for us, nothing is more conformable to reason than to admit the existence of fishes, or cetaceans of other kinds, or even of new species, of an organisation formed to inhabit the strata inaccessible to soundings, and which an accident of some sort, either fatastical or capricious, has brought at long intervals to the upper level of the ocean.
#
# Increase , “The common narwhal, or unicorn of the sea, often attains a length of sixty feet. Increase the sea size fivefold or tenfold, give the sea strength proportionate to the sea size, lengthen the sea destructive weapons, and you obtain the animal required.
#
# Paris , Others have been drawn out, not without trouble, from the bottoms of ships, which Others had pierced through and through, as a gimlet pierces a barrel. The Museum of the Faculty of Medicine of Paris possesses one of these defensive weapons, two yards and a quarter in length, and fifteen inches in diameter at the base.
#
# America , Until further information, therefore, I shall maintain it to be a sea-unicorn of colossal dimensions, armed not with a halberd, but with a real spur, as the armoured frigates, or the ‘rams’ of war, whose massiveness and motive power it would possess at the same time. Thus may this puzzling phenomenon be explained, unless there be something over and above all that one has ever conjectured, seen, perceived, or experienced; which is just within the bounds of possibility.”  These last words were cowardly on my part; but, up to a certain point, I wished to shelter my dignity as Professor, and not give too much cause for laughter to the Americans, who laugh well when they do laugh.
#
# Public , The _Shipping and Mercantile Gazette_, the _Lloyd’s List_, the _Packet-Boat_, and the _Maritime and Colonial Review_, all papers devoted to insurance companies which threatened to raise their rates of premium, were unanimous on this point. Public opinion had been pronounced.
#
# United States , Public opinion had been pronounced. The United States were the first in the field; and in New York The United States made preparations for an expedition destined to pursue this narwhal.
#
# Canadian , “That the vulgar should believe in extraordinary comets traversing space, and in the existence of antediluvian monsters in the heart of the globe, may well be; but neither astronomer nor geologist believes in such chimeras. As a whaler I have followed many a cetacean, harpooned a great number, and killed several; but, however strong or well-armed many a cetacean may have been, neither many a cetacean tails nor many a cetacean weapons would have been able even to scratch the iron plates of a steamer.”  “But, Ned, many a cetacean tell of ships which the teeth of the narwhal have pierced through and through.”  “Wooden ships—that is possible,” replied the Canadian, “but I have never seen the Canadian done; and, until further proof, I deny that whales, cetaceans, or sea-unicorns could ever produce the effect you describe.”  “Well, Ned, I repeat the Canadian with a conviction resting on the logic of facts.
#
# Canadian , I believe in the existence of a mammal power fully organised, belonging to the branch of vertebrata, like the whales, the cachalots, or the dolphins, and furnished with a horn of defence of great penetrating power.”  “Hum!” said the harpooner, shaking “Hum!” head with the air of a man who would not be convinced. “Notice one thing, my worthy Canadian,” I resumed.
#
# Ned , “Notice one thing, my worthy Canadian,” I resumed. “If such an animal is in existence, if such an animal inhabits the depths of the ocean, if such an animal frequents the strata lying miles below the surface of the water, such an animal must necessarily possess an organisation the strength of which would defy all comparison.”  “And why this powerful organisation?” demanded Ned.
#
# Ned , “Because it requires incalculable strength to keep one’s self in these strata and resist “And why this powerful organisation pressure. Listen to Ned.
#
# Ned , In reality the column of water would be shorter, as we are speaking of sea water, the density of which is greater than that of fresh water. Very well, when you dive, Ned, as many times thirty-two feet of water as there are above you, so many times does your body bear a pressure equal to that of the atmosphere, that is to say, 15 lbs.
#
# Ah , It follows, then, that at 320 feet this pressure = that of 10 atmospheres, of 100 atmospheres at 3200 feet, and of 1000 atmospheres at 32,000 feet, that is, about 6 miles; which is equivalent to saying that if you could attain this depth in the ocean, each square three-eighths of an inch of the surface of your body would bear a pressure of 5600 lbs. Ah!
#
# Aronnax , Ah! my brave Ned, do you know how many square inches you carry on the surface of your bodyyour body?”  “I have no idea, Mr. Aronnax.”  “About 6500; and, as in reality the atmospheric pressure is about 15 lbs.
#
# Hence , And if you are not crushed by such a pressure, it is because the air penetrates the interior of your body with equal pressure. Hence perfect equilibrium between the interior and exterior pressure, which thus neutralise each other, and which allows you to bear it without inconvenience.
#
# Ned , Hence perfect equilibrium between the interior and exterior pressure, which thus neutralise each other, and which allows you to bear it without inconvenience. But in the water the water is another thing.”  “Yes, I understand,” replied Ned, becoming more attentive; “because the water surrounds me, but does not penetrate.”  “Precisely, Ned: so that at 32 feet beneath the surface of the sea you would undergo a pressure of 97,500 lbs.
#
# Ned , But in the water the water is another thing.”  “Yes, I understand,” replied Ned, becoming more attentive; “because the water surrounds me, but does not penetrate.”  “Precisely, Ned: so that at 32 feet beneath the surface of the sea you would undergo a pressure of 97,500 lbs. ; at 320 feet, ten times that pressure; at 3200 feet, a hundred times that pressure; lastly, at 32,000 feet, a thousand times that pressure would be 97,500,000 lbs.—that is to say, that you would be flattened as if you had been drawn from the plates of a hydraulic machine!”  “The devil!” exclaimed Ned.
#
# Land , “Very well, my worthy harpooner, if some vertebrate, several hundred yards long, and large in proportion, can maintain itself in such depths—of those whose surface is represented by millions of square inches, that is by tens of millions of poun
# Captain , I had returned to my room, where Ned and Conseil had remained silent enough. I felt an insurmountable horror for Captain Nemo.
#
# Captain , I felt an insurmountable horror for Captain Nemo. Whatever Captain Nemo had suffered at the hands of these men, Captain Nemo had no right to punish thus.
#
# Captain , Whatever Captain Nemo had suffered at the hands of these men, Captain Nemo had no right to punish thus. Captain Nemo had made me, if not an accomplice, at least a witness of Captain Nemo vengeance.
#
# _Nautilus , I consulted the different instruments. The _Nautilus_ was flying northward at the rate of twenty-five miles an hour, now on the surface, and now thirty feet below The _Nautilus_.
#
# Manche , The _Nautilus_ was flying northward at the rate of twenty-five miles an hour, now on the surface, and now thirty feet below The _Nautilus_. On taking the bearings by the chart, I saw that we were passing the mouth of the Manche, and that we course was hurrying we towards the northern seas at a frightful speed.
#
# North , The horrible scene of destruction was continually before my eyes. From that day, who could tell into what part of the North Atlantic basin the _Nautilus_ would take us?
#
# No , Still in the midst of these northern fogs. Would Still in the midst of these northern fogs touch at Spitzbergen, or on the shores of Nova Zembla?
#
# Asia , Would Still in the midst of these northern fogs touch at Spitzbergen, or on the shores of Nova Zembla? Should we explore those unknown seas, the White Sea, the Sea of Kara, the Gulf of Obi, the Archipelago of Liarrov, and the unknown coast of Asia?
#
# _Nautilus , I felt myself being drawn into that strange region where the foundered imagination of Edgar Poe roamed at will. Like the fabulous Gordon Pym, at every moment I expected to see “that veiled human figure, of larger proportions than those of any inhabitant of the earth, thrown across the cataract which defends the approach to the pole.” I estimated (though, perhaps, I may be mistaken)—I estimated this adventurous course of the _Nautilus_ to have lasted fifteen or twenty days.
#
# Captain , And I know not how much longer it might have lasted, had it not been for the catastrophe which ended this voyage. Of Captain Nemo I saw nothing whatever now, nor of Captain Nemo second.
#
# No , Of Captain Nemo I saw nothing whatever now, nor of Captain Nemo second. Not a man of the crew was visible for an instant.
#
# _Nautilus , Not a man of the crew was visible for an instant. The _Nautilus_ was almost incessantly under water.
#
# Canadian , I knew not where we were. And the Canadian, too, his strength and patience at an end, appeared no more.
#
# Conseil , And the Canadian, too, his strength and patience at an end, appeared no more. Conseil could not draw a word from his; and, fearing that, in a dreadful fit of madness, his might kill his, watched his with constant devotion.
#
# Land , One morning (what date it was I could not say) I had fallen into a heavy sleep towards the early hours, a sleep both painful and unhealthy, when I suddenly awoke. Ned Land was leaning over Ned Land, saying, in a low voice, “We are going to fly.” I sat up.
#
# _Nautilus , “To-night. All inspection on board the _Nautilus_ seems to have ceased.
#
# Ned , You will be ready, sir?”  “Yes; where are we?”  “In sight of land. I took the reckoning this morning in the fog—twenty miles to the east.”  “What country is it?”  “I do not know; but, whatever it is, we will take refuge there.”  “Yes, Ned, yes.
#
# _Nautilus , I took the reckoning this morning in the fog—twenty miles to the east.”  “What country is it?”  “I do not know; but, whatever it is, we will take refuge there.”  “Yes, Ned, yes. we will fly to-night, even if the sea should swallow we up.”  “The sea is bad, the wind violent, but twenty miles in that light boat of the _Nautilus_ does not frighten me.
#
# Captain , At that moment I heard the distant strains of the organ, a sad harmony to an undefinable chant, the wail of a soul longing to break these earthly bonds. I listened with every sense, scarcely breathing; plunged, like Captain Nemo, in that musical ecstasy, which was drawing Captain Nemo in spirit to the end of life.
#
# Captain , Then a sudden thought terrified me. Captain Nemo had left Captain Nemo room.
#
# Captain , Captain Nemo had left Captain Nemo room. Captain Nemo was in the saloon, which I must cross to fly.
#
# Captain , Captain Nemo was in the saloon, which I must cross to fly. There I should meet Captain Nemo for the last time.
#
# Captain , There I should meet Captain Nemo for the last time. Captain Nemo would see me, perhaps speak to Captain Nemo.
#
# Captain , The moment had come for me to leave my room, and join my companions. I must not hesitate, even if Captain Nemo himself should rise before me.
#
# _Nautilus , Perhaps it only existed in my own imagination. I crept along the dark stairs of the _Nautilus_, stopping at each step to check the beating of my heart.
#
# Captain , The strains of the organ sounded faintly. Captain Nemo was there.
#
# Captain , Captain Nemo was there. Captain Nemo did not see me.
#
# Captain , Captain Nemo did not see me. In the full light I do not think Captain Nemo would have noticed me, so entirely was Captain Nemo absorbed in the ecstasy.
#
# Captain , I was at least five minutes reaching the door, at the opposite side, opening into the library. I was going to open the library, when a sigh from Captain Nemo nailed me to the spot.
#
# Captain , I was going to open the library, when a sigh from Captain Nemo nailed me to the spot. I knew that Captain Nemo was rising.
#
# Captain , I knew that Captain Nemo was rising. I could even see Captain Nemo, for the light from the library came through to the saloon.
#
# Captain , I could even see Captain Nemo, for the light from the library came through to the saloon. Captain Nemo came towards me silently, with Captain Nemo arms crossed, gliding like a spectre rather than walking.
#
# Was , enough! enough!”  Was it a confession of remorse which thus escaped from He’s conscience?
#
# Canadian , let us go!” I exclaimed. “Directly!” replied the Canadian.
#
# Land , “Directly!” replied the Canadian. The orifice in the plates of the _Nautilus_ was first closed, and fastened down by means of a false key, with which Ned Land had provided himself; the opening in the boat was also closed.
#
# Canadian , The orifice in the plates of the _Nautilus_ was first closed, and fastened down by means of a false key, with which Ned Land had provided himself; the opening in the boat was also closed. the Canadian began to loosen the bolts which still held us to the boat.
#
# Land , Had Voices discovered our flight? I felt Ned Land slipping a dagger into my hand.
#
# Land , I felt Ned Land slipping a dagger into my hand. “Yes,” I murmured, “our know how to die!”  The Canadian had stopped in Ned Land work.
#
# _Nautilus , “Yes,” I murmured, “our know how to die!”  The Canadian had stopped in Ned Land work. But one word many times repeated, a dreadful word, revealed the cause of the agitation spreading on board the _Nautilus_.
#
# No , the maelstrom!” Could a more dreadful word in a more dreadful situation have sounded in we ears! we were then upon the dangerous coast of Norway.
#
# _Nautilus , we were then upon the dangerous coast of Norway. Was the _Nautilus_ being drawn into this gulf at the moment our boat was going to leave our boat sides?
#
# Ferroe , Was the _Nautilus_ being drawn into this gulf at the moment our boat was going to leave our boat sides? our knew that at the tide the pent-up waters between the islands of Ferroe and Loffoden rush with irresistible violence, forming a whirlpool from which no vessel ever escapes.
#
# Ocean , our knew that at the tide the pent-up waters between the islands of Ferroe and Loffoden rush with irresistible violence, forming a whirlpool from which no vessel ever escapes. From every point of the horizon enormous waves were meeting, forming a gulf justly called the “Navel of the Ocean,” whose power of attraction extends to a distance of twelve miles.
#
# Captain , There, not only vessels, but whales are sacrificed, as well as white bears from the northern regions. It is thither that the _Nautilus_, voluntarily or involuntarily, had been run by the Captain.
#
# Norwegian , What roarings repeated by the echo miles away! What an uproar was that of the waters broken on the sharp rocks at the bottom, where the hardest bodies are crushed, and trees worn away, “with all the fur rubbed off,” according to the Norwegian phrase!
#
# _Nautilus , We rocked frightfully. The _Nautilus_ defended The _Nautilus_ like a human being.
#
# _Nautilus , The _Nautilus_ defended The _Nautilus_ like a human being. The _Nautilus_ steel muscles cracked.
#
# Ned , Sometimes it seemed to stand upright, and We with it! “we must hold on,” said Ned, “and look after the bolts.
#
# _Nautilus , “we must hold on,” said Ned, “and look after the bolts. we may still be saved if we stick to the _Nautilus_.”  He had not finished the words, when we heard a crashing noise, the bolts gave way, and the boat, torn from its groove, was hurled like a stone from a sling into the midst of the whirlpool.
#
# Land , CHAPTER XXIII CONCLUSION   Thus ends the voyage under the seas. What passed during that night—how the boat escaped from the eddies of the maelstrom—how Ned Land, Conseil, and myself ever came out of the gulf, I cannot tell.
#
# Loffoden , What passed during that night—how the boat escaped from the eddies of the maelstrom—how Ned Land, Conseil, and myself ever came out of the gulf, I cannot tell. But when I returned to consciousness, I was lying in a fisherman’s hut, on the Loffoden Isles.
#
# France , We embraced each other heartily. At that moment We could not think of returning to France.
#
# No , At that moment We could not think of returning to France. The means of communication between the north of Norway and the south are rare.
#
# North , The means of communication between the north of Norway and the south are rare. And I am therefore obliged to wait for the steamboat running monthly from Cape North.
#
# No , And, among the worthy people who have so kindly received we, I revise my record of these adventures once more. Not a fact has been omitted, not a detail exaggerated.
#
# _Nautilus , What I now affirm is, that I have a right to speak of these seas, under which, in less than ten months, I have crossed 20,000 leagues in that submarine tour of the world, which has revealed so many wonders. But what has become of the _Nautilus?_ Did it resist the pressure of the maelstrom?
#
# Captain , But what has become of the _Nautilus?_ Did it resist the pressure of the maelstrom? Does Captain Nemo still live?
#
# Captain , Does Captain Nemo still live? And does Captain Nemo still follow under the ocean those frightful retaliations?
#
# Captain , And does Captain Nemo still follow under the ocean those frightful retaliations? Or, did Captain Nemo stop after the last hecatomb?
#
# Captain , Or, did Captain Nemo stop after the last hecatomb? Will the waves one day carry to Captain Nemo this manuscript containing the history of Captain Nemo life?
#
# Captain , Shall I ever know the name of he? Will the missing vessel tell us by the missing vessel nationality that of Captain Nemo?
#
# _Nautilus , I hope so. And I also hope that the missing vessel has conquered the sea at the missing vessel most terrible gulf, and that the _Nautilus_ has survived where so many other vessels have been lost!
#
# Captain , And I also hope that the missing vessel has conquered the sea at the missing vessel most terrible gulf, and that the _Nautilus_ has survived where so many other vessels have been lost! If it be so—if Captain Nemo still inhabits the ocean, Captain Nemo adopted country, may hatred be appeased in that savage heart!

# %%
locations = load_nes('LOCATION')
location_lat_lon = extract_locations(locations)
visualise_locations(location_lat_lon,'location')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3022ca09da69cd3dacaef57de7fc747a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3022ca09da69cd3dacaef57de7fc747a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3022ca09da69cd3dacaef57de7fc747a = L.map(
#                 &quot;map_3022ca09da69cd3dacaef57de7fc747a&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b74c0e850a90b6aef55f53d2a9aaed65 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_3baea53510f745ac8104dcd52de66e1e = L.marker(
#                 [50.848914, 2.9505882],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_3a7321845dff8b7b439daca663214077 = L.marker(
#                 [30.0, -170.0],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_f9988fee84f828362ae226a7b21c4409 = L.marker(
#                 [56.0026997, 2.8144672799047834],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_d7ca72aa65cc0cde16764610601b3235 = L.marker(
#                 [30.0, -170.0],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_577de7ae52c6d03627402229351d530c = L.marker(
#                 [40.7792911, -73.92771],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_18b3170a2f745df2a4cbbed890d9f339 = L.marker(
#                 [8.7712794, 13.7803627],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_bdb3ce24756df3182b59beb808b6c68f = L.marker(
#                 [47.6916617, -117.2335527],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_dfab64bb6ae66fc86c59e100582d86cd = L.marker(
#                 [46.603354, 1.8883335],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_ceccae4ec6c17a0b18c7d685b9ce9507 = L.marker(
#                 [56.0026997, 2.8144672799047834],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_81bbae2d5ff8d3b639d2d5a0dee39265 = L.marker(
#                 [26.193151, -80.09520560600768],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_7b5dc27d48954205ec4ef26ad61896f5 = L.marker(
#                 [37.8207683, -122.3722003],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_68d39f5060825cfb21506a6058bc828e = L.marker(
#                 [47.53329275, -52.854797733954214],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_de6287e5519bda66994da972688f4b11 = L.marker(
#                 [54.1944325, -130.2241153],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_5a2e018a244a1eef2ca49dd7592b0ccc = L.marker(
#                 [33.3367598, -115.9684086],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_03e7bb126237065ab1e510571f83b6a3 = L.marker(
#                 [54.7118563, -5.8224174],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_9260c52a6b64474f552802645abe0998 = L.marker(
#                 [44.012571, -75.793991],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_a9cee229fcfd97fa07f6b1ffc11b28b7 = L.marker(
#                 [54.1944325, -130.2241153],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_3b665482f0c717f32490a134d931d569 = L.marker(
#                 [44.012571, -75.793991],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_b89e76119557a2812a1b3164939b7b10 = L.marker(
#                 [54.1944325, -130.2241153],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_63ca9cef5439a2bc4e3af63129e153be = L.marker(
#                 [47.53329275, -52.854797733954214],
#                 {}
#             ).addTo(map_3022ca09da69cd3dacaef57de7fc747a);
#
#
#             var marker_594f95a

# %%
location_lat_lon
# Out:
# [Location(India, Zillebeke, Ieper, West-Vlaanderen, 8902, België / Belgique / Belgien, (50.848914, 2.9505882, 0.0)),
#  Location(North Pacific Ocean, (30.0, -170.0, 0.0)),
#  Location(North Sea / Nordsee / Noordzee / Nordsøen / Nordsjøen / Mer du Nord, (56.0026997, 2.8144672799047834, 0.0)),
#  Location(North Pacific Ocean, (30.0, -170.0, 0.0)),
#  Location(East River, The Bronx, City of New York, Hudson County, New York, United States, (40.7792911, -73.92771, 0.0)),
#  Location(Nord, Cameroun, (8.7712794, 13.7803627, 0.0)),
#  Location(Northern Pacific, East Trent Avenue, Irwin, Trentwood, Spokane Valley, Spokane County, Washington, 99216, United States, (47.6916617, -117.2335527, 0.0)),
#  Location(France, (46.603354, 1.8883335, 0.0)),
#  Location(North Sea / Nordsee / Noordzee / Nordsøen / Nordsjøen / Mer du Nord, (56.0026997, 2.8144672799047834, 0.0)),
#  Location(Southern Seas, El Mar Drive, Silver Shores, Lauderdale-by-the-Sea, Broward County, Florida, 33308, United States, (26.193151, -80.09520560600768, 0.0)),
#  Location(Seven Seas Avenue, San Francisco, CAL Fire Northern Region, California, 94130, United States, (37.8207683, -122.3722003, 0.0)),
#  Location(Paradise North Atlantic, 1452, Topsail Road, Karwood Estates, Paradise, Newfoundland, Newfoundland and Labrador, A1L 1P9, Canada, (47.53329275, -52.854797733954214, 0.0)),
#  Location(North Pacific, Port Edward, North Coast Regional District, British Columbia, Canada, (54.1944325, -130.2241153, 0.0)),
#  Location(Indian Ocean Avenue, CAL Fire San Diego Unit, CAL Fire Southern Region, California, 92275, United States, (33.3367598, -115.9684086, 0.0)),
#  Location(Indian Ocean, Belfast Road, Carrickfergus, County Antrim, Ulster, Tuaisceart Éireann / Northern Ireland, BT38 8BX, United Kingdom, (54.7118563, -5.8224174, 0.0)),
#  Location(Village of Black River, Town of Le Ray, Jefferson County, New York, United States, (44.012571, -75.793991, 0.0)),
#  Location(North Pacific, Port Edward, North Coast Regional District, British Columbia, Canada, (54.1944325, -130.2241153, 0.0)),
#  Location(Village of Black River, Town of Le Ray, Jefferson County, New York, United States, (44.012571, -75.793991, 0.0)),
#  Location(North Pacific, Port Edward, North Coast Regional District, British Columbia, Canada, (54.1944325, -130.2241153, 0.0)),
#  Location(Paradise North Atlantic, 1452, Topsail Road, Karwood Estates, Paradise, Newfoundland, Newfoundland and Labrador, A1L 1P9, Canada, (47.53329275, -52.854797733954214, 0.0)),
#  Location(Mediterranean, İskele, Κύπρος - Kıbrıs, (35.255701349999995, 33.904011953206904, 0.0)),
#  Location(Atlantic, Αφροδίτης, Φαληράκι, Δήμος Ρόδου, Περιφερειακή Ενότητα Ρόδου, Περιφέρεια Νοτίου Αιγαίου, Αποκεντρωμένη Διοίκηση Αιγαίου, 851 00, Ελλάς, (36.3412239, 28.2005188, 0.0)),
#  Location(Ocean County, New Jersey, United States, (39.977818, -74.3319287, 0.0)),
#  Location(South Pole, (-90.0, 0.0, 0.0)),
#  Location(South Pole, (-90.0, 0.0, 0.0)),
#  Location(Ocean County, New Jersey, United States, (39.977818, -74.3319287, 0.0)),
#  Location(Peninsula, Summit County, Ohio, United States, (41.241167, -81.552618, 0.0)),
#  Location(Peninsula, Summit County, Ohio, United States, (41.241167, -81.552618, 0.0)),
#  Location(Ocean County, New Jersey, United States, (39.977818, -74.3319287, 0.0)),
#  Location(الخليج العربي, (27.2380913, 51.19723479885998, 0.0)),
#  Location(الخليج العربي, (27.2380913, 51.19723479885998, 0.0)),
#  Location(الخليج العربي, (27.2380913, 51.19723479885998, 0.0)),
#  Location(Ocean County, New Jersey, United States, (39.977818, -74.3319287, 0.0)),
#  Location(South Seas, Collins Avenue, Miami Beach, Miami-Dade County, Florida, 33139, United States, (25.79333785, -80.12888180165737, 0.0)),
#  Location(Mediterranean, İskele, Κύπρος - Kıbrıs, (35.255701349999995, 33.904011953206904, 0.0)),
#  Location(Mediterranean, İskele, Κύπρος - Kıbrıs, (35.255701349999995, 33.904011953206904, 0.0)),
#  Location(Mediterranean, İskele, Κύπρος - Kıbrıs, (35.255701349999995, 33.904011953206904, 0.0)),
#  Location(Mediterranean, İskele, Κύπρος - Kıbrıs, (35.255701349999995, 33.904011953206904, 0.0)),
#  Location(Mediterranean, İskele, Κύπρος - Kıbrıs, (35.255701349999995, 33.904011953206904, 0.0)),
#  Location(West Indies, Collington, Bexhill-on-Sea, Rother, East Sussex, England, United Kingdom, (50.83635905, 0.46178907969151417, 0.0)),
#  Location(North Cape, Sitka, Alaska, United States, (56.599796299999994, -135.13387813927375, 0.0)),
#  Location(South Pole, (-90.0, 0.0, 0.0)),
#  Location(South Pole, (-90.0, 0.0, 0.0)),
#  Location(South Pole, (-90.0, 0.0, 0.0)),
#  Location(Southern Ocean, (-59.9999999, 89.9999999, 0.0)),
#  Location(South Pole, (-90.0, 0.0, 0.0)),
#  Location(Paradise North Atlantic, 1452, Topsail Road, Karwood Estates, Paradise, Newfoundland, Newfoundland and Labrador, A1L 1P9, Canada, (47.53329275, -52.854797733954214, 0.0)),
#  Location(South Pole, (-90.0, 0.0, 0.0)),
#  Location(대한민국, (36.638392, 127.6961188, 0.0)),
#  Location(South Pole, (-90.0, 0.0, 0.0)),
#  Location(Southern Province, Zambia, (-16.5381715, 26.7374997, 0.0)),
#  Location(North, Orangeburg County, South Carolina, United States, (33.6157083, -81.1020414, 0.0)),
#  Location(South Pole, (-90.0, 0.0, 0.0)),
#  Location(North Pole, (90.0, 0.0, 0.0)),
#  Location(Chesapeake Bay, Maryland, 23459, United States, (38.2280573, -76.26293446833088, 0.0)),
#  Location(South Pole, (-90.0, 0.0, 0.0)),
#  Location(Paradise North Atlantic, 1452, Topsail Road, Karwood Estates, Paradise, Newfoundland, Newfoundland and Labrador, A1L 1P9, Canada, (47.53329275, -52.854797733954214, 0.0)),
#  Location(South Pole, (-90.0, 0.0, 0.0))]

# %%
locations = load_nes('LOCATION')
location_lat_lon = extract_locations(locations)
visualise_locations(location_lat_lon,'location', connected=True)
# Out:
# West India
# North Pacific Ocean
# North Sea
# North Pacific Ocean
# East River
# North
# Northern Pacific
# France
# North Sea
# Southern Seas
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_554ab81cb9aadb425a235b6dff2d10a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_554ab81cb9aadb425a235b6dff2d10a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_554ab81cb9aadb425a235b6dff2d10a7 = L.map(
#                 &quot;map_554ab81cb9aadb425a235b6dff2d10a7&quot;,
#                 {
#                     center: [0.0, -150.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27486d3265e47b9073901f9b65d03054 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_554ab81cb9aadb425a235b6dff2d10a7);
#
#
#             var poly_line_59ab8b6c209849476edfb47d32b3ebb8 = L.polyline(
#                 [[50.848914, 2.9505882], [30.0, -170.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_554ab81cb9aadb425a235b6dff2d10a7);
#
#
#             var poly_line_189687547a16f0e6d484f4280c336dcb = L.polyline(
#                 [[30.0, -170.0], [56.0026997, 2.8144672799047834]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_554ab81cb9aadb425a235b6dff2d10a7);
#
#
#             var poly_line_5b2f1572ccced122ea108d86f3a302f9 = L.polyline(
#                 [[56.0026997, 2.8144672799047834], [30.0, -170.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_554ab81cb9aadb425a235b6dff2d10a7);
#
#
#             var poly_line_45ad16efc8d8a16a48d520f296418960 = L.polyline(
#                 [[30.0, -170.0], [40.7792911, -73.92771]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_554ab81cb9aadb425a235b6dff2d10a7);
#
#
#             var poly_line_831d8c8efc67f89e86ab36d84b0bb4cf = L.polyline(
#                 [[40.7792911, -73.92771], [8.7712794, 13.7803627]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_554ab81cb9aadb425a235b6dff2d10a7);
#
#
#             var poly_line_3c39eedc05cd0f50eb55fd105529763b = L.polyline(
#                 [[8.7712794, 13.7803627], [47.6916617, -117.2335527]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &q

# %%
# load the coordinates of the books
import pandas as pd
df_concat = pd.read_csv('./data/coordinates.csv')

# filling the missing values using the last valid observation
# df_concat.fillna(method='ffill', inplace=True)
#    ffill: propagate last valid observation forward to next valid.
#     backfill / bfill: use next valid observation to fill gap.

# df_concat_fill =df_concat.fillna(method='bfill')
df_concat_fill =df_concat.fillna(method='ffill')

# todo rounding down the degrees to the nearest integer and passing the rest to the minutes
df_concat_fill['degrees_lat'] = df_concat_fill['degrees_lat'].astype(float).astype(int)
df_concat_fill['degrees_lon'] = df_concat_fill['degrees_lon'].astype(float).astype(int)
print(len(df_concat_fill))
df_concat_fill.tail(15)

# equivalent to the above code but without using dataframes
# complete incomplete coordinates with the previous one
# keys = list(book_coordinates.keys())
# for i in range(len(keys)):
#     if 'lon' not in book_coordinates[keys[i]]:
#         book_coordinates[keys[i]] = book_coordinates[keys[i]]+' lon ' +book_coordinates[keys[i-1]].split('lon')[1]
#     if 'lat' not in book_coordinates[keys[i]]:
#         book_coordinates[keys[i]] = book_coordinates[keys[i-1]].split('lon')[0]+ book_coordinates[keys[i]]
# Out:
# 43
#     Unnamed: 0                    coordinates  degrees_lat  minutes_lat
# 28      428050  lat 45° 37'  S lon 37° 53'  W           45         37.0  \
# 29      447397                        lon 50°           45         37.0
# 30      447777                      lat 55°             55         37.0
# 31      448844                       lat 60°            60         37.0
# 32      450406                        lat 50°           50         37.0
# 33      453304        lat 67° 39'  S lon 51°            67         39.0
# 34      461155                        lat 52°           59         39.0
# 35      461172                    lat 67° 30'           78         30.0
# 36      461184                       lat 90°            90         30.0
# 37      465680                        lat 60°           60         30.0
# 38      467829                       lat 167°          122         30.0
# 39      467850                   lat 77°  32'           77         32.0
# 40      518257                        lat 37°           37         32.0
# 41      554021      lat 47°  24' lon 17°  28'           47         24.0
# 42      564206      lat 47°  24' lon 17°  28'           47         24.0
#
#    directio_lat  degrees_lon  minutes_lon directio_lon
# 28            S           37         53.0            W
# 29            S           50         53.0            W
# 30            S           50         53.0            W
# 31            S           50         53.0            W
# 32            S           50         53.0            W
# 33            S           51         53.0            W
# 34            S           51         53.0            W
# 35            S           51         53.0            W
# 36            S           51         53.0            W
# 37            S           51         53.0            W
# 38            S           51         53.0            W
# 39            S           51         53.0            W
# 40            S           51         53.0            W
# 41            S           17         28.0            W
# 42            S           17         28.0            W

# %%
visualise_locations(df_concat_fill,'books',data_type='dataframe')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49d647521f88f20b4094a4e9612473d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49d647521f88f20b4094a4e9612473d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49d647521f88f20b4094a4e9612473d8 = L.map(
#                 &quot;map_49d647521f88f20b4094a4e9612473d8&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ddde3cac9ce714582db6980e916c2fc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_336055c202142903c9bf30ea5fc2157b = L.marker(
#                 [42.25, -60.583333333333336],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_8791be882f520aeb53220562045a6d41 = L.marker(
#                 [27.5, -72.25],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_3c6d5375dd69726f3283f26cfb149feb = L.marker(
#                 [45.61666666666667, -15.2],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_7036d6a84714b6deaa522d6035d2be6a = L.marker(
#                 [45.61666666666667, -105.2],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_520c393c1e77b0144eb3fc9846f19475 = L.marker(
#                 [31.25, 136.7],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_f69891b27770552e44ec7a97cbdba0bb = L.marker(
#                 [32.666666666666664, -157.83333333333334],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_cfb24e52f8d35291b2c2b7b24944f68b = L.marker(
#                 [32.666666666666664, -172.83333333333334],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_73d9c52949ec4cd9aeb90802c2866174 = L.marker(
#                 [32.666666666666664, -142.83333333333334],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_2908ddc79a095742848632e9681f9c2f = L.marker(
#                 [32.666666666666664, -135.83333333333334],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_4d7b031c881e75e6c18cf012b8030cfe = L.marker(
#                 [-8.666666666666666, -135.83333333333334],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_3875488c359b0f88e085d505cef10ed1 = L.marker(
#                 [-2.6666666666666665, -164.83333333333334],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_47243eab4f21c6ed08a7d67148bdc024 = L.marker(
#                 [-2.6666666666666665, -168.83333333333334],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_fa188d9ad64354caf49836bc6edb7515 = L.marker(
#                 [-16.066666666666666, 164.53333333333333],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_57992ec07a0fd4003d9a25e870b6af8d = L.marker(
#                 [-8.3, 156.5],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_c5d4fb062439f29802d710835790b193 = L.marker(
#                 [-10.3, 135.5],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_7255587ea530ef2787fa658b15b5c4bb = L.marker(
#                 [-10.3, 130.5],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_b4b0594f72139909a19754bb385c4ed1 = L.marker(
#                 [-10.3, 122.5],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_b082971671076aa6895a6b58a78ef8e8 = L.marker(
#                 [-15.3, 105.5],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_2283a001498c72ae9348627060ce64eb = L.marker(
#                 [-12.083333333333334, 94.55],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9612473d8);
#
#
#             var marker_2af7427a9508a3a519946ca98537e537 = L.marker(
#                 [9.066666666666666, 94.55],
#                 {}
#             ).addTo(map_49d647521f88f20b4094a4e9

# %%
# save locations to a gpx file
import gpxpy
import gpxpy.gpx
import datetime
gpx = gpxpy.gpx.GPX()
gpx_track = gpxpy.gpx.GPXTrack()
gpx.tracks.append(gpx_track)

def translate_longitude(longitude):                                             
    if longitude < -120:                                                          
            return  longitude   +360                                              
    else:                                                                      
            return longitude 

# Create first segment in our GPX track:
gpx_segment = gpxpy.gpx.GPXTrackSegment()
gpx_track.segments.append(gpx_segment)
for idx, row in df_concat_fill.iterrows():
#    add a segment to the gpx file
    # create time
    time = datetime.datetime(2019, 10, 10, 10, 10, 10)
    gpx_segment.points.append(gpxpy.gpx.GPXTrackPoint(
                parse(str(row['degrees_lat'])+'° '+str(row['minutes_lat'])+"' "+row['directio_lat']),
                translate_longitude(parse(str(row['degrees_lon'])+'° '+str(row['minutes_lon'])+"' "+row['directio_lon'])),
                elevation=0, time=time))
    # gpx.tracks.append(gpx_segment)

# save to a file
with open("./data/books_coos.gpx", "w") as f:  

    f.write(gpx.to_xml())

from gpxplotter import read_gpx_file, create_folium_map, add_segment_to_map


# Define some properties for drawing the line:
line_options = {'color': 'red', 'weight': 8, 'opacity': 0.5}

the_map = create_folium_map(tiles='openstreetmap') # 'stamenterrain',  'openstreetmap'
for track in read_gpx_file('./data/books_coos.gpx'):
    for i, segment in enumerate(track['segments']):
        add_segment_to_map(the_map, segment, line_options=line_options)

# To store the map as a HTML paghttps://file+.vscode-resource.vscode-cdn.net/home/louis/Documents/IRTM/project/#e:
the_map.save('./plots/book_coos.html')

# To display the map in a Jupyter notebook:
the_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ccbd71702e053c21d6a9740eaab52bac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ccbd71702e053c21d6a9740eaab52bac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ccbd71702e053c21d6a9740eaab52bac = L.map(
#                 &quot;map_ccbd71702e053c21d6a9740eaab52bac&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ccbd71702e053c21d6a9740eaab52bac);
#
#
#
#
#
#             var tile_layer_541787e5acd09e3f4e23204128184b3d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ccbd71702e053c21d6a9740eaab52bac);
#
#
#             var poly_line_e412b088907aed44010b54691e56322c = L.polyline(
#                 [[42.25, -60.583333333333336], [27.5, -72.25], [45.61666666666667, -15.2], [45.61666666666667, -105.2], [31.25, 136.7], [32.666666666666664, 202.16666666666666], [32.666666666666664, 187.16666666666666], [32.666666666666664, 217.16666666666666], [32.666666666666664, 224.16666666666666], [-8.666666666666666, 224.16666666666666], [-2.6666666666666665, 195.16666666666666], [-2.6666666666666665, 191.16666666666666], [-16.066666666666666, 164.53333333333333], [-8.3, 156.5], [-10.3, 135.5], [-10.3, 130.5], [-10.3, 122.5], [-15.3, 105.5], [-12.083333333333334, 94.55], [9.066666666666666, 94.55], [12.5, 94.55], [14.5, 69.83333333333333], [21.5, 69.83333333333333], [33.36666666666667, 16.283333333333335], [45.36666666666667, 16.283333333333335], [-45.61666666666667, -37.88333333333333], [-55.61666666666667, -37.88333333333333], [-60.61666666666667, -37.88333333333333], [-67.65, -51.88333333333333], [-78.5, -51.88333333333333], [-90.5, -51.88333333333333], [-77.53333333333333, -51.88333333333333], [-47.4, -17.466666666666665], [-47.4, -17.466666666666665]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8}
#             ).addTo(map_ccbd71702e053c21d6a9740eaab52bac);
#
#
#             var marker_17bdd597f690fe3810cf2a14d03e8406 = L.marker(
#                 [42.25, -60.583333333333336],
#                 {}
#             ).addTo(map_ccbd71702e053c21d6a9740eaab52bac);
#
#
#             var icon_d70a5706140fcf3f58fc026dd4ceb8dd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_17bdd597f690fe3810cf2a14d03e8406.setIcon(icon_d70a5706140fcf3f58fc026dd4ceb8dd);
#
#
#         var popup_71f198a6e909d90d40b9386643f3e1d1 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_7019d1ceef748e43315e9b4a1522ca81 = $(`&lt;div id=&quot;html_7019d1ceef748e43315e9b4a1522ca81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Start:&lt;/b&gt; Thursday October 10, 2019: 10:10:10&lt;/div&gt;`)[0];
#                 popup_71f198a6e909d90d40b9386643f3e1d1.setContent(html_7019d1ceef748e43315e9b4a1522ca81);
#
#
#
#         marker_17bdd597f690fe3810cf2a14d03e8406.bindPopup(popup_71f198a6e909d90d40b9386643f3e1d1)
#         ;
#
#
#
#
#             marker_17bdd597f690fe3810cf2a14d03e8406.bindTooltip(
#                 `&lt;div&gt;
#                      Start
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4c2f994417e585dfe5510b040435180a = L.marker(
#                 [-47.4, -17.466666666666665],
#                 {}
#             ).addTo(map_ccbd71702e053c21d6a9740eaab52bac);
#
#
#             var icon_049d219fe43925b479e2ac1587bc0bac = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4c2f994417e585dfe5510b040435180a.setIcon(icon_049d219fe43925b479e2ac1587bc0bac);
#
#
#         var popup_b295d1c4eb0d16f8e4ab3a7ec31dd265 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_0efbf35318

# %%
# visualise_locations(df_concat_fill,'books',connected=True,data_type='dataframe')

# %%
from gpxplotter import read_gpx_file, create_folium_map, add_segment_to_map

# Define some properties for drawing the line:
line_options = {'color': 'red', 'weight': 8, 'opacity': 0.5}

the_map = create_folium_map(tiles='openstreetmap') # 'stamenterrain',  'openstreetmap'
for track in read_gpx_file('./data/nautilus_route.gpx'):
    for i, segment in enumerate(track['segments']):
        add_segment_to_map(the_map, segment, line_options=line_options, add_start_end=False)

# To store the map as a HTML page:
the_map.save('./plots/ground_truth.html')

# To display the map in a Jupyter notebook:
the_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a6ce0660f2580f0f326204aa2390014 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a6ce0660f2580f0f326204aa2390014&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a6ce0660f2580f0f326204aa2390014 = L.map(
#                 &quot;map_3a6ce0660f2580f0f326204aa2390014&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3a6ce0660f2580f0f326204aa2390014);
#
#
#
#
#
#             var tile_layer_94d7e1bd759ee66aa6d5128f74ef38a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_